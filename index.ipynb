# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#new_cols = [col.lower() for col in df.columns]
df.columns = df.columns.str.lower()
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
df.rename(df.linename, axis='index')
# Out:
#            c/a  unit       scp        station linename division        date  \
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# NQR456W   A002  R051  02-00-00          59 ST  NQR456W      BMT  08/26/2018
# ...

# %% [markdown]
# ## Painstakingly change the index back

# %%
df.reset_index()
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
#df['Num_Lines'] = df.linename.map(lambda x: len(x))
df['Num_Lines']= df.apply(lambda x: len(x['linename']), axis=1)
df.sort_values(by=['Num_Lines'])
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.strip()#Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries    exits  Num_Lines
# 0  REGULAR  6736067  2283184          7
# 1  REGULAR  6736087  2283188          7
# 2  REGULAR  6736105  2283229          7
# 3  REGULAR  6736180  2283314          7
# 4  REGULAR  6736349  2283384          7

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.date = pd.to_datetime(df.date)
df['day_of_week'] = df.date.dt.dayofweek

grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
print(grouped)
df.head()
# Out:
#                    entries         exits  Num_Lines
# day_of_week
# 0            1114237052454  911938153513      76110
# 1            1143313287046  942230721477      77303
# 2            1123655222441  920630864687      75713
# 3            1122723988662  920691927110      76607
# 4            1110224700078  906799065337      75573
# 5            1115661545514  909142081474      74725
# 6            1192306179082  959223750461      75306
#     c/a  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  Num_Lines  day_of_week
# 0  REGULAR  6736067  2283184          7            5
# ...

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
import numpy as np
#Your code here

#grouped = grouped.reset_index()
#grouped.head()

#grouped['is_weekend'] = grouped.day_of_week.map({0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True})
#take the mean, not the sum

#group = df.groupby('day_of_week').sum()
#weekend.plot(kind='barh')
weekday_entries = df.groupby('day_of_week').mean().loc[:4,'entries'].mean()
weekend_exit = df.groupby('day_of_week').mean().loc[5:,'entries'].mean()
weekend_entries= df.groupby('day_of_week').mean().loc[5:,'exits'].mean()
weekday_exit = df.groupby('day_of_week').mean().loc[:4,'exits'].mean()

plt.bar([1, 2, 3, 4],[weekday_entries, weekday_exit, weekend_entries, weekend_exit])

plt.xlabel()
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here
df.drop(['Num_Lines', 'day_of_week'], axis=1)
df.head()
# Out:
#     c/a  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries    exits  Num_Lines  day_of_week
# 0  REGULAR  6736067  2283184          7            5
# 1  REGULAR  6736087  2283188          7            5
# 2  REGULAR  6736105  2283229          7            5
# 3  REGULAR  6736180  2283314          7            5
# 4  REGULAR  6736349  2283384          7            5

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
